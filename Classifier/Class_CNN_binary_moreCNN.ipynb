# %%
# import tensorflow as tf
# tf.config.list_physical_devices(device_type='GPU')

# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %% [markdown]
# ### Bibliotecas

# %%
import os
import tensorflow as tf
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint, ReduceLROnPlateau,TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, BatchNormalization, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras.optimizers import  Adam  #, SGD , Adam

from keras.preprocessing import image as keras_image
import keras

# %% [markdown]
# ### Dataset

# %%
### Definir paths em meu computador                 

Path_open_csv =  '/home/karem/Artigo_Periodico/1_Dataset/CSV_Files/'
Path_images =  '/home/karem/Artigo_Periodico/1_Dataset/1_Original_size640/'
Path_save =  '/home/karem/Artigo_Periodico/Classifier/Experiment/'  ## definir pasta onde salvar pesos e log


term_imagem = '.png'

### Definir parâmetros
width = 32*8*1 # *2 = imagem com tamanho 512x512 e *1 = imagem com tamanho 256x256
height = 32*8*1
depth = 3  # 3 se RGB, 1 se grayscale (weights_ini= None)
inputShape  = [height, width, depth]


################################################################################################
#                   carregar e montar csv de treino e validação
################################################################################################

#******************* Train data *******************************
data_train = pd.DataFrame()
data_train_temp = pd.read_csv(Path_open_csv + 'train.csv').rename(columns={'id': 'image_id', 'class_name': 'label'})
data_train_temp['label'].replace({'negative': 0, 'typical': 1, 'indeterminate': 1}, inplace=True)

data_train_temp['Image_name'] = data_train_temp['image_id'].replace('_image', '', regex=True) + term_imagem
data_train = data_train_temp[['Image_name', 'label']]
#***************************************************************


#******************* Val data **********************************
data_val = pd.DataFrame()
data_val_temp = pd.read_csv(Path_open_csv + 'val.csv' ).rename(columns={'id': 'image_id', 'class_name': 'label'})
data_val_temp['label'].replace({'negative': 0, 'typical': 1, 'indeterminate': 1}, inplace=True)

data_val_temp['Image_name'] =  data_val_temp['image_id'].replace('_image', '', regex=True) + term_imagem
data_val = data_val_temp[['Image_name', 'label']]
#del data_train_temp, data_val_temp
#***************************************************************

#### montar vector normal=0 anormal=1
data_val['classVector']   =  data_val['label']
data_train['classVector'] =  data_train['label']
   
data_train['Image_Index'] =  Path_images + data_train['Image_name'] 
data_val['Image_Index']   =  Path_images + data_val['Image_name']  
del data_train_temp, data_val_temp
# Out:
# /home/karem/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/karem/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/karem/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/karem/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Dados de salvamento

# %%
def create_folders(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

# %%
# rede = ['DenseNet121', 'DenseNet169', 'DenseNet201', \
#         'InceptionV3', 'InceptionResNetV2', \
#         'MobileNet', 'MobileNetV2', \
#         'NASNetLarge', 'NASNetMobile', \
#         'ResNet50', 'ResNet101', 'ResNet152', 'ResNet50V2', 'ResNet101V2', 'ResNet152V2', \
#         'VGG16', 'VGG19', \
#         'Xception']

# rede = ['EfficientNetB0', 'EfficientNetB1', 'EfficientNetB2', 'EfficientNetB3', 'EfficientNetB4', \
#         #'EfficientNetB5', 'EfficientNetB6', 'EfficientNetB7', \
#         ]

# %%
rede = 'NASNetMobile'
#'NASNetLarge' #'DenseNet201', 'MobileNetV2', 'ResNet50V2', 'VGG19', 'VGG16', 'EfficientNetB0', 'EfficientNetB4'
#'Xception', 'InceptionV3', 'InceptionResNetV2'
weights_ini = 'imagenet'  # 'imagenet'  None
NUM_EPOCHS = 80
BATCH_SIZE = 8

# %%
################################################################################################
#                                Dados do treino 
################################################################################################

l_nome_proceso = 'CNN_mlp'
n_salv         = 'CNN_mlp_temp'

experimento = l_nome_proceso + '_WH_' + str(width) 
### Estabelecer path para salvar resultados e pesos do experimento
Path_save_peso  =  Path_save + '/Models/' + experimento +  '/'
Path_save_logs  =  Path_save + '/logs/'   + experimento +  '/'
### Criar pastas onde serão salvados os pesos do experimento
create_folders(Path_save_peso)

### definir nomes de arquivos de saida
palavra_s            = 'ensaio_' + rede +  '_'  + weights_ini + '_WH_' + str(width)       
arquivo_saida        = os.path.sep.join([Path_save_peso, "R_"+ palavra_s + ".hdf5"]) 
arquivo_saida_best_w = os.path.sep.join([Path_save_peso, "W_"+ palavra_s + "best_W.hdf5"]) 
arquivo_saida_histo  = os.path.sep.join([Path_save_peso, "H_"+ palavra_s + "Hist.pkl"]) 

### definir pasta para armazenar o Log
log_dir3  = Path_save_logs + palavra_s + '/'
create_folders(log_dir3)

# %% [markdown]
# ### Image Generator

# %%
class Data_GeneratorRx(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, data_path_img, data_lab, index_b, batch_size=BATCH_SIZE, inputShape=inputShape, aug = 0, shuffle=True):            
        'Initialization'
        if aug == 1:
            data_gen = ImageDataGenerator(  
                                        rotation_range     = 15,
                                        # zoom_range         = 0.05,
                                        width_shift_range  = 0.1,
                                        height_shift_range = 0.1,
                                        # shear_range        = 0.01,
                                        horizontal_flip    = True,
                                        fill_mode          = "nearest",
                                        preprocessing_function = preprocess_input,
                                        )
        else:
            data_gen = ImageDataGenerator(
                                    preprocessing_function = preprocess_input, # se usar isto a imagem entrada deve ficar 0-255
                                 )            
        self.data_path_img  =  data_path_img   
        self.labels         =  data_lab   
        self.index_b        =  index_b    
        self.batch_size     =  batch_size # int
        self.inputShape     =  inputShape               # tuple int)
        self.data_gen       =  data_gen
        self.shuffle        =  shuffle
        self.aug            =  aug
        self.on_epoch_end()
        
####################################################################################################################################
    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch        """
        return int(np.ceil( len(self.data_path_img)  /  float(self.batch_size) ))
    
####################################################################################################################################
    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        ## Generate indexes of the batch
        indexes = self.index_b[index * self.batch_size:(index + 1) * self.batch_size]
        ## Find list of IDs (paths)
        list_IDs_temp = [self.data_path_img[k] for k in indexes]
        ## Generate data
        X = self._generate_X(list_IDs_temp)
        y = self.labels[indexes]                
        ## Generate Augmented data
        iterat = self.data_gen.flow(X, y, shuffle=self.shuffle)
        X0,y0  = iterat.next()
        y_mat  = np.array(np.uint32 (y0.tolist()) )
        return X0,y_mat
    
####################################################################################################################################
    def _generate_X(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of image paths to load
        :return: batch of images
        """
        # Initialization
        X = np.empty( (len(list_IDs_temp), *self.inputShape) )
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            X[i,] = self._load_image(ID)
        return X
    
####################################################################################################################################
    def _load_image(self, image_path):
        """Load grayscale image
        :param image_path: path to image to load
        :return: loaded image
        """
        img = keras_image.load_img(image_path ,target_size=self.inputShape,interpolation='bicubic',color_mode = "rgb")
        img = 255.0*np.array(img) / (1.0*np.nanmax(img))
        return img   #  [0,255]
    
####################################################################################################################################
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.index_b = np.arange(len(self.data_path_img))
        if self.shuffle == True:
            np.random.shuffle(self.index_b)

# %% [markdown]
# ### Rede

# %%
def get_model(model_name, model_weights_ini, inputShape):        
    if model_name == 'ResNet50':          
        base_model = ResNet50(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'ResNet101':          
        base_model = ResNet101(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    if model_name == 'ResNet152':          
        base_model = ResNet152(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name   == 'ResNet50V2':                 
        base_model = ResNet50V2(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name   == 'ResNet101V2':                 
        base_model = ResNet101V2(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name   == 'ResNet152V2':                 
        base_model = ResNet152V2(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'VGG16':          
        base_model = VGG16(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'VGG19':            
        base_model = VGG19(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
        
    elif model_name == 'EfficientNetB0':  
        base_model = EfficientNetB0(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'EfficientNetB1':  
        base_model = EfficientNetB1(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'EfficientNetB2':  
        base_model = EfficientNetB2(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'EfficientNetB3':  
        base_model = EfficientNetB3(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'EfficientNetB4':        
        base_model = EfficientNetB4(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
    
    elif model_name == 'EfficientNetB5':  
        base_model = EfficientNetB5(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'EfficientNetB6':  
        base_model = EfficientNetB6(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
    
    elif model_name == 'EfficientNetB7':  
        base_model = EfficientNetB7(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))
        
    elif model_name == 'MobileNetV2':             
        base_model = MobileNetV2(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape)) 
    
    elif model_name == 'MobileNet':             
        base_model = MobileNet(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape)) 
    
    elif model_name == 'DenseNet121':
        base_model = DenseNet121(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
    
    elif model_name == 'DenseNet169':
        base_model = DenseNet169(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
    
    elif model_name == 'DenseNet201':
        base_model = DenseNet201(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
    
    elif model_name == 'NASNetLarge':
        base_model = NASNetLarge(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape)) 
    
    elif model_name == 'NASNetMobile':
        base_model = NASNetMobile(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape)) 
    
    elif model_name == 'Xception':             
        base_model = Xception(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
        
    elif model_name == 'InceptionV3':             
        base_model = InceptionV3(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
        
    elif model_name == 'InceptionResNetV2':             
        base_model = InceptionResNetV2(include_top=False,  weights = model_weights_ini, input_tensor=Input(shape=inputShape))   
    return base_model

# %%
if rede == 'ResNet50': 
    from tensorflow.keras.applications import ResNet50
    from tensorflow.keras.applications.resnet50 import preprocess_input
elif rede == 'ResNet101': 
    from tensorflow.keras.applications import ResNet101
    from tensorflow.keras.applications.resnet import preprocess_input
elif rede == 'ResNet152': 
    from tensorflow.keras.applications import ResNet152
    from tensorflow.keras.applications.resnet import preprocess_input
elif rede == 'ResNet50V2': 
    from tensorflow.keras.applications import ResNet50V2
    from tensorflow.keras.applications.resnet_v2 import preprocess_input
elif rede == 'ResNet101V2': 
    from tensorflow.keras.applications import ResNet101V2
    from tensorflow.keras.applications.resnet_v2 import preprocess_input
elif rede == 'ResNet152V2': 
    from tensorflow.keras.applications import ResNet152V2
    from tensorflow.keras.applications.resnet_v2 import preprocess_input
elif rede == 'VGG16': 
    from tensorflow.keras.applications import VGG16
    from tensorflow.keras.applications.vgg16 import preprocess_input
elif rede == 'VGG19': 
    from tensorflow.keras.applications import VGG19
    from tensorflow.keras.applications.vgg19 import preprocess_input
elif rede == 'EfficientNetB0':
    from keras_efficientnets import  EfficientNetB0
    from keras_efficientnets import  preprocess_input  
elif rede == 'EfficientNetB1':
    from keras_efficientnets import  EfficientNetB1
    from keras_efficientnets import  preprocess_input  
elif rede == 'EfficientNetB2':
    from keras_efficientnets import  EfficientNetB2
    from keras_efficientnets import  preprocess_input  
elif rede == 'EfficientNetB3':
    from keras_efficientnets import  EfficientNetB3
    from keras_efficientnets import  preprocess_input  
elif rede == 'EfficientNetB4': 
    from keras_efficientnets import  EfficientNetB4
    from keras_efficientnets import  preprocess_input
elif rede == 'EfficientNetB5': 
    from keras_efficientnets import  EfficientNetB5
    from keras_efficientnets import  preprocess_input
elif rede == 'EfficientNetB6': 
    from keras_efficientnets import  EfficientNetB6
    from keras_efficientnets import  preprocess_input
elif rede == 'EfficientNetB7': 
    from keras_efficientnets import  EfficientNetB7
    from keras_efficientnets import  preprocess_input
elif rede == 'MobileNetV2': 
    from tensorflow.keras.applications import MobileNetV2
    from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
elif rede == 'MobileNet': 
    from tensorflow.keras.applications import MobileNet
    from tensorflow.keras.applications.mobilenet import preprocess_input
elif rede == 'DenseNet201': 
    from tensorflow.keras.applications import DenseNet201
    from tensorflow.keras.applications.densenet import preprocess_input
elif rede == 'DenseNet121': 
    from tensorflow.keras.applications import DenseNet121
    from tensorflow.keras.applications.densenet import preprocess_input
elif rede == 'DenseNet169': 
    from tensorflow.keras.applications import DenseNet169
    from tensorflow.keras.applications.densenet import preprocess_input
elif rede == 'NASNetLarge': 
    from tensorflow.keras.applications import NASNetLarge
    from tensorflow.keras.applications.nasnet import preprocess_input    
elif rede == 'NASNetMobile': 
    from tensorflow.keras.applications import NASNetMobile
    from tensorflow.keras.applications.nasnet import preprocess_input    
elif rede == 'Xception': 
    from tensorflow.keras.applications import Xception
    from tensorflow.keras.applications.xception import preprocess_input    
elif rede == 'InceptionV3': 
    from tensorflow.keras.applications import InceptionV3
    from tensorflow.keras.applications.inception_v3 import preprocess_input    
elif rede == 'InceptionResNetV2': 
    from tensorflow.keras.applications import InceptionResNetV2
    from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input

# %%
### definir dictionario para apontador dentro do generator
paramsB = {
              'batch_size': BATCH_SIZE,
              'inputShape': inputShape,
          }

# %%
################################################################################################
#                  Montar CONV net
################################################################################################
##  carregar modelo base
base_model = get_model(rede, weights_ini, inputShape)
## construir MLP
headModel = base_model.output
headModel = GlobalAveragePooling2D()(headModel)
headModel = BatchNormalization()(headModel)

headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.3)(headModel)                      # orig = 0.5
headModel = Dense(1, activation="sigmoid", name="pred")(headModel)

## place the head FC model on top of the base model (this will become the actual model we will train)
model = Model(inputs=base_model.input, outputs=headModel, name="Classifica")


## Treinar toda a base menos as layer BatchNormalization
for layer in base_model.layers:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True    

## compile our model (this needs to be done after our setting our layers to being non-trainable
print("[INFO] compiling model...")
model.compile( 
                loss      = 'binary_crossentropy',  
                optimizer = Adam(lr = 1e-4),
                metrics   = ['accuracy', 'mae'] 
             )     
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 0s 0us/step
# [INFO] compiling model...
# Model: "Classifica"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 127, 127, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 127, 127, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 127, 127, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 127, 127, 11) 352         activation[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 127, 127, 11) 44          reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 127, 127, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 127, 127, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 131, 131, 11) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 133, 133, 32) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 64, 64, 11)   396         separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 64, 64, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 64, 64, 11)   44          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 64, 64, 11)   44          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 64, 64, 11)   396         activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 64, 64, 11)   660         activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 127, 127, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 64, 64, 11)   44          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 64, 64, 11)   44          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 133, 133, 32) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 127, 127, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 64, 64, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 64, 64, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 131, 131, 32) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 64, 64, 11)   44          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 64, 64, 11)   1152        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 64, 64, 11)   220         activation_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 64, 64, 11)   44          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 64, 64, 11)   44          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 129, 129, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 64, 64, 11)   660         activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 64, 64, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 64, 64, 11)   44          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 64, 64, 11)   396         activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 64, 64, 11)   220         activation_10[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 127, 127, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 64, 64, 11)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 64, 64, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 64, 64, 11)   44          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 64, 64, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 64, 64, 11)   44          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 64, 64, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 128, 128, 32) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 64, 64, 11)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 11)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 64, 64, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 127, 127, 32) 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 64, 64, 44)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 64, 64, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 64, 64, 32)   0           cropping2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 64, 64, 11)   352         adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 64, 64, 11)   352         adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 64, 64, 22)   968         activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 22)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 64, 64, 22)   88          reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 64, 64, 22)   88          concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 67, 67, 22)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 69, 69, 22)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 32, 32, 22)   1034        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 32, 32, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 32, 32, 22)   88          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 32, 32, 22)   88          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 32, 32, 22)   1034        activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 32, 32, 22)   1562        activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 32, 32, 22)   88          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 32, 32, 22)   88          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 69, 69, 22)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 32, 32, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 32, 32, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 67, 67, 22)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 32, 32, 22)   88          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 32, 32, 22)   1034        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 32, 32, 22)   682         activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 32, 32, 22)   88          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 32, 32, 22)   88          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 65, 65, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 32, 32, 22)   1562        activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 32, 32, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 32, 32, 22)   88          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 32, 32, 22)   1034        activation_19[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 32, 32, 22)   682         activation_21[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 64, 64, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 32, 32, 22)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 32, 32, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 32, 32, 22)   88          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 32, 32, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 32, 32, 22)   88          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 32, 32, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 65, 65, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 32, 32, 22)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 22)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 32, 32, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 64, 64, 44)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 32, 32, 88)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 32, 32, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 32, 32, 44)   0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 32, 32, 22)   968         adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 32, 32, 22)   968         adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 44)   0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 32, 32, 44)   3872        activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 32, 32, 44)   176         concatenate_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 32, 32, 44)   176         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 32, 32, 44)   3036        activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 32, 32, 44)   2332        activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 32, 32, 44)   3036        activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 32, 32, 44)   2332        activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 32, 32, 44)   2332        activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 32, 32, 44)   3036        activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 32, 32, 44)   2332        activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 32, 32, 44)   3036        activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 32, 32, 44)   2332        activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 32, 32, 44)   2332        activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 32, 32, 44)   176         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 32, 32, 44)   176         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 32, 32, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 32, 32, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 32, 32, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 32, 32, 44)   176         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 32, 32, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 32, 32, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 32, 32, 44)   0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 32, 32, 44)   0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 32, 32, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 32, 32, 264)  0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 32, 32, 44)   3872        activation_33[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 32, 32, 44)   11616       activation_34[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 32, 32, 44)   176         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 32, 32, 44)   176         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 32, 32, 44)   3036        activation_35[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 32, 32, 44)   2332        activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 32, 32, 44)   3036        activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 32, 32, 44)   2332        activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 32, 32, 44)   2332        activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 32, 32, 44)   3036        activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 32, 32, 44)   2332        activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 32, 32, 44)   3036        activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 32, 32, 44)   2332        activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 32, 32, 44)   2332        activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 32, 32, 44)   176         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 32, 32, 44)   176         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 32, 32, 44)   176         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 32, 32, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 32, 32, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 32, 32, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 32, 32, 44)   176         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 32, 32, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 32, 32, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 32, 32, 44)   0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 32, 32, 44)   0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 32, 32, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 32, 32, 264)  0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 32, 264)  0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 32, 32, 44)   11616       activation_45[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 32, 32, 44)   11616       activation_46[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 32, 32, 44)   176         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 32, 32, 44)   176         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 32, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 32, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 32, 32, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 32, 32, 44)   3036        activation_47[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 32, 32, 44)   2332        activation_49[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 32, 32, 44)   3036        activation_51[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 32, 32, 44)   2332        activation_53[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 32, 32, 44)   2332        activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 32, 32, 44)   176         separable_conv_1_normal_left1_2[0
# ...
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 8, 8, 176)    32560       activation_168[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 8, 8, 176)    35376       activation_170[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 8, 8, 176)    32560       activation_172[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 8, 8, 176)    32560       activation_174[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 8, 8, 176)    704         separable_conv_2_normal_left1_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 8, 8, 176)    704         separable_conv_2_normal_right1_11
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 8, 8, 176)    704         separable_conv_2_normal_left2_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 8, 8, 176)    704         separable_conv_2_normal_right2_11
# __________________________________________________________________________________________________
# normal_left3_11 (AveragePooling (None, 8, 8, 176)    0           normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_left4_11 (AveragePooling (None, 8, 8, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_right4_11 (AveragePoolin (None, 8, 8, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 8, 8, 176)    704         separable_conv_2_normal_left5_11[
# __________________________________________________________________________________________________
# normal_add_1_11 (Add)           (None, 8, 8, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_11 (Add)           (None, 8, 8, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_11 (Add)           (None, 8, 8, 176)    0           normal_left3_11[0][0]
#                                                                  adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_add_4_11 (Add)           (None, 8, 8, 176)    0           normal_left4_11[0][0]
#                                                                  normal_right4_11[0][0]
# __________________________________________________________________________________________________
# normal_add_5_11 (Add)           (None, 8, 8, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_concat_11 (Concatenate)  (None, 8, 8, 1056)   0           adjust_bn_11[0][0]
#                                                                  normal_add_1_11[0][0]
#                                                                  normal_add_2_11[0][0]
#                                                                  normal_add_3_11[0][0]
#                                                                  normal_add_4_11[0][0]
#                                                                  normal_add_5_11[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 8, 8, 1056)   0           normal_concat_10[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 8, 8, 1056)   0           normal_concat_11[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_12 (Conv (None, 8, 8, 176)    185856      activation_175[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_12 (Conv2D)       (None, 8, 8, 176)    185856      activation_176[0][0]
# __________________________________________________________________________________________________
# adjust_bn_12 (BatchNormalizatio (None, 8, 8, 176)    704         adjust_conv_projection_12[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_12 (BatchNormalizat (None, 8, 8, 176)    704         normal_conv_1_12[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 8, 8, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 8, 8, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 8, 8, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 8, 8, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 8, 8, 176)    35376       activation_177[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 8, 8, 176)    32560       activation_179[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 8, 8, 176)    35376       activation_181[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 8, 8, 176)    32560       activation_183[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 8, 8, 176)    32560       activation_185[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 8, 8, 176)    704         separable_conv_1_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 8, 8, 176)    704         separable_conv_1_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 8, 8, 176)    704         separable_conv_1_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 8, 8, 176)    704         separable_conv_1_normal_right2_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 8, 8, 176)    704         separable_conv_1_normal_left5_12[
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 8, 8, 176)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 8, 8, 176)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 8, 8, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 8, 8, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 8, 8, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 8, 8, 176)    35376       activation_178[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 8, 8, 176)    32560       activation_180[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 8, 8, 176)    35376       activation_182[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 8, 8, 176)    32560       activation_184[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 8, 8, 176)    32560       activation_186[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 8, 8, 176)    704         separable_conv_2_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 8, 8, 176)    704         separable_conv_2_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 8, 8, 176)    704         separable_conv_2_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 8, 8, 176)    704         separable_conv_2_normal_right2_12
# __________________________________________________________________________________________________
# normal_left3_12 (AveragePooling (None, 8, 8, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_left4_12 (AveragePooling (None, 8, 8, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_right4_12 (AveragePoolin (None, 8, 8, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 8, 8, 176)    704         separable_conv_2_normal_left5_12[
# __________________________________________________________________________________________________
# normal_add_1_12 (Add)           (None, 8, 8, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_12 (Add)           (None, 8, 8, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_12 (Add)           (None, 8, 8, 176)    0           normal_left3_12[0][0]
#                                                                  adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_add_4_12 (Add)           (None, 8, 8, 176)    0           normal_left4_12[0][0]
#                                                                  normal_right4_12[0][0]
# __________________________________________________________________________________________________
# normal_add_5_12 (Add)           (None, 8, 8, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_concat_12 (Concatenate)  (None, 8, 8, 1056)   0           adjust_bn_12[0][0]
#                                                                  normal_add_1_12[0][0]
#                                                                  normal_add_2_12[0][0]
#                                                                  normal_add_3_12[0][0]
#                                                                  normal_add_4_12[0][0]
#                                                                  normal_add_5_12[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 8, 8, 1056)   0           normal_concat_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1056)         0           activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1056)         4224        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          270592      batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# pred (Dense)                    (None, 1)            257         dropout[0][0]
# ==================================================================================================
# Total params: 4,544,789
# Trainable params: 4,505,939
# Non-trainable params: 38,850
# __________________________________________________________________________________________________

# %%
### Montar generator para leitura dos dados      
n_treino = len(data_train)
index_t  = np.arange(n_treino)

np.random.shuffle(index_t)
np.random.shuffle(index_t)
np.random.shuffle(index_t)

training_generator   = Data_GeneratorRx(data_path_img = data_train['Image_Index'], data_lab = data_train['classVector'], index_b = index_t, **paramsB, aug = 1)
validation_generator = Data_GeneratorRx(data_path_img = data_val['Image_Index'], data_lab = data_val['classVector'], index_b = np.arange(len(data_val)), **paramsB, aug = 0,shuffle = False)

# %%
### create callback
Arquivo_temp_peso = Path_save_peso  + palavra_s + '.hdf5'
es        = EarlyStopping(monitor='val_loss', patience= 10, mode='auto', verbose=1)
mc        = ModelCheckpoint(Arquivo_temp_peso , monitor='val_loss', save_best_only=True, mode='auto', verbose=1)
tensorboard_callback = TensorBoard(log_dir=log_dir3, histogram_freq=1)
Rp        = ReduceLROnPlateau(
                        monitor="val_loss", factor=0.2, patience=7,
                        verbose=1, mode="auto", min_lr=1e-6,                        
                            )

# %%
### Treinar
H = model.fit(
            training_generator,
            validation_data = validation_generator,
            epochs          = NUM_EPOCHS,
            callbacks       = [mc, es, tensorboard_callback, Rp],
            steps_per_epoch = np.ceil(len(index_t) / BATCH_SIZE),
            verbose         = 1,
            shuffle         = True
        )
# Out:
# Epoch 1/80
# 603/603 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.7345 - mae: 0.3167
# Epoch 00001: val_loss improved from inf to 0.53940, saving model to /home/karem/Artigo_Periodico/Classifier/Experiment//Models/CNN_mlp_WH_256/ensaio_NASNetMobile_imagenet_WH_256.hdf5
# 603/603 [==============================] - 222s 369ms/step - loss: 0.5688 - accuracy: 0.7345 - mae: 0.3167 - val_loss: 0.5394 - val_accuracy: 0.7087 - val_mae: 0.3600 - lr: 1.0000e-04
# Epoch 2/80
# 603/603 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7631 - mae: 0.2814
# Epoch 00002: val_loss improved from 0.53940 to 0.45188, saving model to /home/karem/Artigo_Periodico/Classifier/Experiment//Models/CNN_mlp_WH_256/ensaio_NASNetMobile_imagenet_WH_256.hdf5
# 603/603 [==============================] - 99s 164ms/step - loss: 0.4934 - accuracy: 0.7631 - mae: 0.2814 - val_loss: 0.4519 - val_accuracy: 0.7835 - val_mae: 0.2822 - lr: 1.0000e-04
# Epoch 3/80
# 603/603 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7872 - mae: 0.2684
# Epoch 00003: val_loss did not improve from 0.45188
# 603/603 [==============================] - 98s 162ms/step - loss: 0.4639 - accuracy: 0.7872 - mae: 0.2684 - val_loss: 0.5286 - val_accuracy: 0.7441 - val_mae: 0.3272 - lr: 1.0000e-04
# Epoch 4/80
# 603/603 [==============================] - ETA: 0s - loss: 0.4486 - accuracy: 0.7859 - mae: 0.2628
# Epoch 00004: val_loss did not improve from 0.45188
# 603/603 [==============================] - 98s 162ms/step - loss: 0.4486 - accuracy: 0.7859 - mae: 0.2628 - val_loss: 0.5660 - val_accuracy: 0.7244 - val_mae: 0.3629 - lr: 1.0000e-04
# Epoch 5/80
# 603/603 [==============================] - ETA: 0s - loss: 0.4274 - accuracy: 0.7998 - mae: 0.2541
# Epoch 00005: val_loss did not improve from 0.45188
# 603/603 [==============================] - 98s 163ms/step - loss: 0.4274 - accuracy: 0.7998 - mae: 0.2541 - val_loss: 0.4583 - val_accuracy: 0.7756 - val_mae: 0.2658 - lr: 1.0000e-04
# Epoch 6/80
# 603/603 [==============================] - ETA: 0s - loss: 0.4068 - accuracy: 0.8073 - mae: 0.2501
# Epoch 00006: val_loss did not improve from 0.45188
# 603/603 [==============================] - 98s 163ms/step - loss: 0.4068 - accuracy: 0.8073 - mae: 0.2501 - val_loss: 0.4982 - val_accuracy: 0.7677 - val_mae: 0.2680 - lr: 1.0000e-04
# Epoch 7/80
# 603/603 [==============================] - ETA: 0s - loss: 0.4054 - accuracy: 0.8119 - mae: 0.2505
# Epoch 00007: val_loss did not improve from 0.45188
# 603/603 [==============================] - 98s 163ms/step - loss: 0.4054 - accuracy: 0.8119 - mae: 0.2505 - val_loss: 0.6609 - val_accuracy: 0.7677 - val_mae: 0.2434 - lr: 1.0000e-04
# Epoch 8/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3868 - accuracy: 0.8260 - mae: 0.2358
# Epoch 00008: val_loss did not improve from 0.45188
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3868 - accuracy: 0.8260 - mae: 0.2358 - val_loss: 0.4678 - val_accuracy: 0.7992 - val_mae: 0.2453 - lr: 1.0000e-04
# Epoch 9/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8222 - mae: 0.2342
# Epoch 00009: val_loss improved from 0.45188 to 0.42121, saving model to /home/karem/Artigo_Periodico/Classifier/Experiment//Models/CNN_mlp_WH_256/ensaio_NASNetMobile_imagenet_WH_256.hdf5
# 603/603 [==============================] - 99s 165ms/step - loss: 0.3759 - accuracy: 0.8222 - mae: 0.2342 - val_loss: 0.4212 - val_accuracy: 0.8031 - val_mae: 0.2526 - lr: 1.0000e-04
# Epoch 10/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8139 - mae: 0.2359
# Epoch 00010: val_loss improved from 0.42121 to 0.40693, saving model to /home/karem/Artigo_Periodico/Classifier/Experiment//Models/CNN_mlp_WH_256/ensaio_NASNetMobile_imagenet_WH_256.hdf5
# 603/603 [==============================] - 100s 165ms/step - loss: 0.3848 - accuracy: 0.8139 - mae: 0.2359 - val_loss: 0.4069 - val_accuracy: 0.8583 - val_mae: 0.2852 - lr: 1.0000e-04
# Epoch 11/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3739 - accuracy: 0.8336 - mae: 0.2302
# Epoch 00011: val_loss did not improve from 0.40693
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3739 - accuracy: 0.8336 - mae: 0.2302 - val_loss: 0.4085 - val_accuracy: 0.8110 - val_mae: 0.2758 - lr: 1.0000e-04
# Epoch 12/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8339 - mae: 0.2199
# Epoch 00012: val_loss did not improve from 0.40693
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3607 - accuracy: 0.8339 - mae: 0.2199 - val_loss: 0.4256 - val_accuracy: 0.8071 - val_mae: 0.2303 - lr: 1.0000e-04
# Epoch 13/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.8413 - mae: 0.2145
# Epoch 00013: val_loss improved from 0.40693 to 0.40050, saving model to /home/karem/Artigo_Periodico/Classifier/Experiment//Models/CNN_mlp_WH_256/ensaio_NASNetMobile_imagenet_WH_256.hdf5
# 603/603 [==============================] - 99s 165ms/step - loss: 0.3492 - accuracy: 0.8413 - mae: 0.2145 - val_loss: 0.4005 - val_accuracy: 0.8071 - val_mae: 0.2579 - lr: 1.0000e-04
# Epoch 14/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3503 - accuracy: 0.8446 - mae: 0.2136
# Epoch 00014: val_loss did not improve from 0.40050
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3503 - accuracy: 0.8446 - mae: 0.2136 - val_loss: 0.5051 - val_accuracy: 0.7717 - val_mae: 0.2920 - lr: 1.0000e-04
# Epoch 15/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.8527 - mae: 0.2049
# Epoch 00015: val_loss did not improve from 0.40050
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3313 - accuracy: 0.8527 - mae: 0.2049 - val_loss: 0.4279 - val_accuracy: 0.8110 - val_mae: 0.2518 - lr: 1.0000e-04
# Epoch 16/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.8596 - mae: 0.1951
# Epoch 00016: val_loss did not improve from 0.40050
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3219 - accuracy: 0.8596 - mae: 0.1951 - val_loss: 0.4422 - val_accuracy: 0.8189 - val_mae: 0.2366 - lr: 1.0000e-04
# Epoch 17/80
# 603/603 [==============================] - ETA: 0s - loss: 0.3110 - accuracy: 0.8612 - mae: 0.1899
# Epoch 00017: val_loss did not improve from 0.40050
# 603/603 [==============================] - 98s 163ms/step - loss: 0.3110 - accuracy: 0.8612 - mae: 0.1899 - val_loss: 0.7242 - val_accuracy: 0.6811 - val_mae: 0.3247 - lr: 1.0000e-04
# Epoch 18/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.8702 - mae: 0.1792
# Epoch 00018: val_loss improved from 0.40050 to 0.39934, saving model to /home/karem/Artigo_Periodico/Classifier/Experiment//Models/CNN_mlp_WH_256/ensaio_NASNetMobile_imagenet_WH_256.hdf5
# 603/603 [==============================] - 100s 165ms/step - loss: 0.2882 - accuracy: 0.8702 - mae: 0.1792 - val_loss: 0.3993 - val_accuracy: 0.8150 - val_mae: 0.2181 - lr: 1.0000e-04
# Epoch 19/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.8747 - mae: 0.1794
# Epoch 00019: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.2979 - accuracy: 0.8747 - mae: 0.1794 - val_loss: 0.5879 - val_accuracy: 0.7165 - val_mae: 0.3217 - lr: 1.0000e-04
# Epoch 20/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.8811 - mae: 0.1625
# Epoch 00020: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.2678 - accuracy: 0.8811 - mae: 0.1625 - val_loss: 0.4151 - val_accuracy: 0.8307 - val_mae: 0.2228 - lr: 1.0000e-04
# Epoch 21/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.8867 - mae: 0.1604
# Epoch 00021: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.2743 - accuracy: 0.8867 - mae: 0.1604 - val_loss: 0.4916 - val_accuracy: 0.8150 - val_mae: 0.2407 - lr: 1.0000e-04
# Epoch 22/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.8907 - mae: 0.1519
# Epoch 00022: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.2458 - accuracy: 0.8907 - mae: 0.1519 - val_loss: 0.9365 - val_accuracy: 0.6732 - val_mae: 0.3280 - lr: 1.0000e-04
# Epoch 23/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9017 - mae: 0.1421
# Epoch 00023: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.2330 - accuracy: 0.9017 - mae: 0.1421 - val_loss: 0.5360 - val_accuracy: 0.7953 - val_mae: 0.2373 - lr: 1.0000e-04
# Epoch 24/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9087 - mae: 0.1373
# Epoch 00024: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.2275 - accuracy: 0.9087 - mae: 0.1373 - val_loss: 0.7182 - val_accuracy: 0.7480 - val_mae: 0.2733 - lr: 1.0000e-04
# Epoch 25/80
# 603/603 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9065 - mae: 0.1326
# Epoch 00025: val_loss did not improve from 0.39934
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 603/603 [==============================] - 99s 164ms/step - loss: 0.2254 - accuracy: 0.9065 - mae: 0.1326 - val_loss: 1.0706 - val_accuracy: 0.6063 - val_mae: 0.3844 - lr: 1.0000e-04
# Epoch 26/80
# 603/603 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9363 - mae: 0.1082
# Epoch 00026: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.1671 - accuracy: 0.9363 - mae: 0.1082 - val_loss: 1.0737 - val_accuracy: 0.6417 - val_mae: 0.3494 - lr: 2.0000e-05
# Epoch 27/80
# 603/603 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9398 - mae: 0.0915
# Epoch 00027: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.1462 - accuracy: 0.9398 - mae: 0.0915 - val_loss: 0.9711 - val_accuracy: 0.6850 - val_mae: 0.3174 - lr: 2.0000e-05
# Epoch 28/80
# 603/603 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9494 - mae: 0.0804
# Epoch 00028: val_loss did not improve from 0.39934
# 603/603 [==============================] - 98s 163ms/step - loss: 0.1325 - accuracy: 0.9494 - mae: 0.0804 - val_loss: 0.9079 - val_accuracy: 0.7126 - val_mae: 0.2950 - lr: 2.0000e-05
# Epoch 00028: early stopping

# %%
#!python -c 'import tensorflow as tf; print(tf.__version__)'

# %%
# !python --version

# %%
##tensorboard --logdir /home/karem/7_Rede_Diego/DataClassify_8/Padchest_Normal_vs_NonNormal_WithoutBones/Experiment/logs/CNN_mlp_WH_256/ensaio_EfficientNetB0_imagenet_WH_256/ --port=6007

# %%
# os.remove("/home/karem/5_Redes/Rede_ArtigoSPIE/Covid19_RadiograpyDataset/COVID/.ipynb_checkpoints") # specifying the path of the file

# %%
# os.remove("/home/karem/5_Redes/Rede_ArtigoSPIE/Covid19_RadiograpyDataset/COVID/COVID-698.png'
